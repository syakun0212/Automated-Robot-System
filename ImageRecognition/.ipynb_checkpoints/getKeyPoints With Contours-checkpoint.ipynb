# %%
import math
import random
import time

import numpy as np
import cv2 as cv

import sklearn.cluster

# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
def indexAxes(axes, i, ncols, nrows):
    if( (ncols == 1) and nrows == 1):
        return axes
    elif(ncols == 1 or nrows == 1):
        return axes[i]
    else:
        I = i // ncols
        J = i % ncols
        return axes[I][J]
    
def showImages(images, title=None, ncols=1, nrows=1):
    fig, ax = plt.subplots(ncols=ncols, nrows=nrows)
    for i,img in enumerate(images):
        if(len(img.shape) == 2):
            h,w = img.shape
            c = 1
        else:
            h,w,c = img.shape
        
        I = i // ncols
        J = i % ncols
        
        if(c == 3):
            imgC = cv.cvtColor(img, cv.COLOR_RGB2BGR)
            indexAxes(ax, i, ncols, nrows).imshow(imgC)
        else:
            indexAxes(ax, i, ncols, nrows).imshow(img, cmap=plt.cm.gray)
            
        if(title is not None and i < len(title)):
            indexAxes(ax, i, ncols, nrows).set_title(title[i])
    
    return fig, ax

def drawLines(src, lines, color=[255,0,0]):
    img = src
    for i in range(len(lines)):
        line = lines[i][0]
        img = cv.line(img, (line[0], line[1]), (line[2], line[3]), color=color)
    return img

def grayToRGB(src):
    return np.stack([src.copy(), src.copy(), src.copy()], -1)

def drawPixels(src, points, color=[255,0,0]):
    img = src
    img[points[:,1], points[:,0]] = color
    return img

def getSubtreeCount(hierachy, node): # node [next, prev, child, parent, index]
    count = 0
    childInd = node[2]
    if(childInd == -1):
        return 1
    child = hierachy[node[2]]
    while(True):
        count += getSubtreeCount(hierachy, hierachy[child[4]]) + 1
        if(child[0] == -1):
            break
        child = hierachy[child[0]]
    return count

def hierachySearch(hierachy):
    index = np.arange(len(hierachy[0]))
    h = np.concatenate([hierachy[0], np.expand_dims(index, -1)], 1)
    
    noParents = h[:,3] == -1
    
    noParentsIndex = index[noParents]
    
    counts = []
    
    for i in noParentsIndex:
        counts.append((i,getSubtreeCount(h, h[i])))
    print(counts)
    return max(counts, key=lambda x: x[1])

# %%
imgRaw = cv.imread("bulleye07.png")
imgG = cv.cvtColor(imgRaw, cv.COLOR_RGB2GRAY)
#imgE = cv.equalizeHist(imgG)
_, imgBin = cv.threshold(imgG, 60, 255, cv.THRESH_OTSU) # 60

# %%
fig1, ax1 = showImages([imgRaw, imgG, imgBin], title=["Raw", "Gray", "Binary"], ncols=3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sharpenFilter = np.array([[0, -3, 0],
                          [-3, 13, -3],
                          [0, -3, 0]])
imgSharp = cv.filter2D(imgG, -1, sharpenFilter)

# %%
_, imgSharpBin = cv.threshold(imgSharp, 60, 255, cv.THRESH_OTSU)

# %%
fig2, ax2 = showImages([imgG, imgBin, imgSharp, imgSharpBin], title=["Gray", "Binary", "Sharp", "Sharp Bin"], ncols=4)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(f"Gray Contrast:\t\t{imgG.std():.05f}")
print(f"Bin Contrast:\t\t{imgBin.std():.05f}")
print(f"Sharp Contrast:\t\t{imgSharp.std():.05f}")
print(f"Sharp Bin Contrast:\t{imgSharpBin.std():.05f}")
# Out:
# Gray Contrast:		19.79573
# Bin Contrast:		112.95257
# Sharp Contrast:		64.49207
# Sharp Bin Contrast:	91.57413

# %%
imgCanny = cv.Canny(imgSharpBin, 1, 25, None ,3)
fig3, ax3 = showImages([imgCanny], ["Canny"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines = cv.HoughLinesP(imgCanny, 1, math.pi/180, 7)
lines.shape
# Out:
# (108, 1, 4)

# %%
imgSharpLines = drawLines(grayToRGB(imgG), lines)

# %%
fig4, ax4 = showImages([imgSharpBin, imgSharpLines], ["Sharp Binary", "Sharp Lines"], ncols=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
contours_1, hierachy_1 = cv.findContours(imgBin,  cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
len(contours_1)
# thresh = cv2.erode(thresh, None, iterations=2)
# thresh = cv2.dilate(thresh, None, iterations=2)
# Out:
# 8

# %%
maxInd_1, maxCount_1 = hierachySearch(hierachy_1)
print(maxInd_1, maxCount_1)
# Out:
# [(0, 1), (1, 6), (7, 1)]
# 1 6

# %%
contours_2, hierachy_2 = cv.findContours(imgSharpBin,  cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
len(contours_2)
# Out:
# 7

# %%
def find_approx(contours):
# loop over the contours
    corners = []
    cnts = sorted(contours, key = cv.contourArea, reverse = True)[:5]
    for c in cnts:
        area = cv.contourArea(c)
        print(area)
        if area > 0:
            approxErr1 = 0.02*cv.arcLength(c, True)
            approxPoly1 = cv.approxPolyDP(c, approxErr1, True)
            
            print(approxPoly1)
            # if our approximated contour has four points, then we
            # can assume that we have found our screen
            if len(approxPoly1) == 4:
                corners = approxPoly1
                return corners
        
    return corners

def order_points(pts):
    
    dst_pts = pts[:,0]
    # Initialize the order in a clockwise dir (top_left, top_right, btm_left, btm_right)
    rect = np.zeros((4, 2), dtype=float)

    # the top-left point will have the smallest sum, whereas
    # the bottom-right point will have the largest sum
    s = dst_pts.sum(axis = 1)
    rect[0] = dst_pts[np.argmin(s)]
    rect[3] = dst_pts[np.argmax(s)]

    # now, compute the difference between the points, the
    # top-right point will have the smallest difference,
    # whereas the bottom-left will have the largest difference
    diff = np.diff(dst_pts, axis = 1)
    rect[1] = dst_pts[np.argmin(diff)]
    rect[2] = dst_pts[np.argmax(diff)]

    return rect

# %%
import pickle
import cv2

calib_result_pickle = pickle.load(open("new_camera_calib_pickle.p", "rb" ))
mtx = calib_result_pickle["mtx"]
optimal_camera_matrix = calib_result_pickle["optimal_camera_matrix"]
dist = calib_result_pickle["dist"]
roi = calib_result_pickle["roi"]

imgCrop = cv.imread("symbols/00bulleye.png")

# %%
src_pts = np.array([[14,14], [84,14], [14,84], [84,84]], dtype=float) # top_left, top_right, btm_right, btm_left
src_pts
# Out:
# array([[14., 14.],
#        [84., 14.],
#        [14., 84.],
#        [84., 84.]])

# %%
cnts = sorted(contours_1, key = cv.contourArea, reverse = True)[:5] # will the largets contourarea
print(cv.contourArea(cnts[0]))
area = cv.contourArea(cnts[0])

print(area)
hull = cv.convexHull(cnts[0])
approxErr1 = 0.02*cv.arcLength(hull, True)
approxPoly1 = cv.approxPolyDP(hull, approxErr1, True)
approxPoly1
# Out:
# 1025.0
# 1025.0
# array([[[ 7,  6]],
#
#        [[29,  9]],
#
#        [[26, 52]],
#
#        [[ 5, 52]]], dtype=int32)

# %%
corners = order_points(approxPoly1)
corners
# Out:
# array([[ 7.,  6.],
#        [29.,  9.],
#        [ 5., 52.],
#        [26., 52.]])

# %%
maxInd_2, maxCount_2 = hierachySearch(hierachy_2)
print(maxInd_2, maxCount_2)
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1), (6, 1)]
# 0 1

# %%
boundingCont = contours_2[maxInd_2]
boundingCH = cv.convexHull(boundingCont)
approxErr2 = 0.02*cv.arcLength(boundingCH, True)
approxPoly2 = cv.approxPolyDP(boundingCH, approxErr2, True)
approxPoly2
# Out:
# array([[[37, 52]],
#
#        [[37, 38]]], dtype=int32)

# %%
imgBoundApprox1 = drawPixels(imgRaw.copy(), np.array(corners, dtype=int))
imgBoundApprox2 = drawPixels(imgRaw.copy(), approxPoly2[:,0])

# %%
fig7, ax7 = showImages([imgRaw, imgBoundApprox1, imgBoundApprox2], ["Raw Img", "Bounding Approximation 1", "Bounding Approximation 2"], ncols=3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
symScale = 13/0.008
pi_image_size = (480,640)

#Image Stuff
image_size = (416, 416)

src_points = src_pts

# imageScale
modelScale = np.array([ p / m for p,m in zip(pi_image_size, image_size) ])
# src_coord = np.hstack([np.multiply(src_points/symScale - np.array([[0.03,0.15]]), modelScale), np.zeros((len(src_points), 1))])
# src_coord

src_coord = np.hstack([np.multiply(src_points/symScale, modelScale), np.zeros((len(src_points), 1))])
src_coord
# Out:
# array([[0.00994083, 0.01325444, 0.        ],
#        [0.05964497, 0.01325444, 0.        ],
#        [0.00994083, 0.07952663, 0.        ],
#        [0.05964497, 0.07952663, 0.        ]])

# %%
def rotationMatrixToEulerAngles(R) :
    sy = math.sqrt(R[0,0] * R[0,0] +  R[1,0] * R[1,0])

    singular = sy < 1e-6

    if  not singular :
        x = math.atan2(R[2,1] , R[2,2])
        y = math.atan2(-R[2,0], sy)
        z = math.atan2(R[1,0], R[0,0])
    else :
        x = math.atan2(-R[1,2], R[1,1])
        y = math.atan2(-R[2,0], sy)
        z = 0

    return np.array([x, y, z])

pi = math.pi
_, rvec, tvec = cv.solvePnP(src_coord, corners, optimal_camera_matrix, dist)

rotMat, jac = cv.Rodrigues(rvec)
eulerAngle = rotationMatrixToEulerAngles(rotMat)
print(f"Rotation Vector from SolvePnP: \n{eulerAngle * 180/math.pi} \nTranslation Vector: \n{tvec}")

rotation_matrix = np.zeros(shape=(3,3))
cv2.Rodrigues(rvec, rotation_matrix)

#Apply rotation matrix to point
original_point = np.matrix([[1],[0],[0]])
rotated_point = rotation_matrix*original_point
print("wDF: ",rotated_point)
# Out:
# Rotation Vector from SolvePnP:
# [ 93.95055451 -68.0837255  -75.77565188]
# Translation Vector:
# [[-0.4513027 ]
#  [-0.35061193]
#  [ 0.69031128]]
# wDF:  [[ 0.09171506]
#  [-0.36180781]
#  [ 0.92773027]]

# %%
H, status = cv.findHomography(src_pts, corners, cv.RANSAC,0.005) # return H (homograph matrix)src_points, dst_points
num, Rs, Ts, Ns  = cv.decomposeHomographyMat(H, optimal_camera_matrix)

for r, t in zip(Rs, Ts):
    eulerAngle = rotationMatrixToEulerAngles(r)
    print(f"Rotation Vector from Decompose: \n{eulerAngle * 180/math.pi} \n \nTranslation\n {t}")
# Out:
# Rotation Vector from Decompose:
# [ 8.03606159 10.31048264 -0.07426082]
#
# Translation
#  [[-1.77696985]
#  [-0.5830759 ]
#  [ 1.82960637]]
# Rotation Vector from Decompose:
# [ 8.03606159 10.31048264 -0.07426082]
#
# Translation
#  [[ 1.77696985]
#  [ 0.5830759 ]
#  [-1.82960637]]
# Rotation Vector from Decompose:
# [110.51982027 -71.16177892 -85.65113492]
#
# Translation
#  [[-0.34596084]
#  [-0.20899459]
#  [ 2.58489675]]
# Rotation Vector from Decompose:
# [110.51982027 -71.16177892 -85.65113492]
#
# Translation
#  [[ 0.34596084]
#  [ 0.20899459]
#  [-2.58489675]]

# %%
import numpy as np
tvec = np.array([[-0.03],[0],[0.13]]).flatten()

grid_size = 10

real_Y = np.round(((tvec[2]/1.25)*100 - grid_size)/grid_size) + 1 # +1 grid because the robot to the block is another 10cm (1grid)

test_Y = ((tvec[2]/1.25)*100 - grid_size)/grid_size
print(test_Y)
move_Z = (((tvec[2]*100)/1.25)-grid_size)/grid_size
dummy_X = np.round((tvec[0] + 0.03 + (0.03)*(move_Z))*grid_size)
real_X = tvec[0] + 0.03 + (0.03)*(move_Z)

if dummy_X == 0:
    direction = "front"
elif real_X < 0:
    direction = "left"
    left_offset = -0.03
    real_X = round((real_X + left_offset) * grid_size)
    real_X *= -1
else:
    direction = "right"
    right_offset = 0.03
    real_X = round((real_X + right_offset) * grid_size)
    
print("HELLO: ", tvec[0] + 0.03 + (0.03)*(move_Z))
print(f"Obstacle Detected: X-axis {int(real_X)} block to the {direction}, Y-axis: {int(real_Y)} block away")
# Out:
# 0.040000000000000036
# HELLO:  0.001200000000000001
# Obstacle Detected: X-axis 0 block to the front, Y-axis: 1 block away

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20, 20))
columns = 3
rows = 3
imagepath_list = [image_path for image_path in os.listdir(path)]

for i in range(1,columns*rows +1):
    img = cv2.imread(path + "/" + imagepath_list[i-1])
    fig.add_subplot(rows, columns, i)
    plt.rcParams["figure.figsize"] = (5,5)
    plt.imshow(img)
    if len(imagepath_list) == i:
        break
plt.show()
